# %% [markdown]
# <a href="https://colab.research.google.com/github/sorialexis00-ctrl/prac-exer.py/blob/main/prac_exer_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))
if num % 2 == 0 :
  print('The number is even.')
else:
  print('The number is odd.')
